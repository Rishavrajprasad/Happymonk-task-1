# %% [markdown]
# **Installing Utralytics**

# %%
# !pip install ultralytics

# %% [markdown]
# **Importing YOLO form ultralytics**

# %%
from ultralytics import YOLO

# %% [markdown]
# **Mounting Google Drive for importing files**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLOv8
# Out:
# /content/drive/MyDrive/YOLOv8

# %%
# !ls
# Out:
# data  data.yaml

# %% [markdown]
# **Installing YOLOv8 in the directory**

# %%
# %cd /content/drive/MyDrive/YOLOv8
model = YOLO("yolov8m.pt")
# Out:
# /content/drive/MyDrive/YOLOv8
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 74.3MB/s]

# %% [markdown]
# **Training YOLOv8 with Custom dataset especially to detect person only**

# %%
model.train(data="data.yaml", epochs=30)

# %%
results = model.predict("https://upload.wikimedia.org/wikipedia/commons/3/37/Tanchangya_women.jpg")
# Out:
# ...
# 100%|██████████| 129k/129k [00:00<00:00, 891kB/s]
# image 1/1 /content/drive/MyDrive/YOLOv8/Tanchangya_women.jpg: 448x640 8 persons, 70.6ms
# Speed: 2.2ms preprocess, 70.6ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)

# %%
result = results[0]

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=720x476>
